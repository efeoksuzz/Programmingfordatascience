# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\kygm\Desktop\city.csv",sep='|',header=1)
data.info()

# %%
missing_values = data.isnull().sum()
data = data.dropna()   

duplicate_count = data.duplicated().sum()
data = data.drop_duplicates()

# %%
print(data.shape)
# Out:
# (5, 15)

# %%
#2. a) Which country appears most frequently in the dataset? How many cities are associated with it?
data[['city', 'country']] = data['City'].str.split(',', expand=True)
countries_count = data['country'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 2
#       1 #2. a) Which country appears most frequently in the dataset? How many cities are associated with it?
# ----> 2 data[['city', 'country']] = data['City'].str.split(',', expand=True)
#       3 countries_count = data['country'].value_counts()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4304, in DataFrame.__setitem__(self, key, value)
#    4302     self._setitem_frame(key, value)
#    4303 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4304     self._setitem_array(key, value)
#    4305 elif isinstance(value, DataFrame):
#    4306     self._set_item_frame_value(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4346, in DataFrame._setitem_array(self, key, value)
#    4341 else:
#    4342     # Note: unlike self.iloc[:, indexer] = value, this will
# ...
